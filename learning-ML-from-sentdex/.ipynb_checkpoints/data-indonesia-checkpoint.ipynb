# %%
import pandas as pd
import quandl
import math

# %% [markdown]
# Code | Details |
# ---- | ------- |
# UENV/WNFI_IDN	| Net Freshwater Supplied by Water Supply Industry in Indonesia |
# UENV/XMWC_IDN |	Municipal Waste Collected in Indonesia |
# UENV/WGFA_IDN |	Gross Freshwater Abstracted in Indonesia |
# BP/C02_EMMISSIONS_IDN | BP CO_2 Emission from BP |

# %%
df_wnfi = quandl.get('UENV/WNFI_IDN')
df_xmwc = quandl.get('UENV/XMWC_IDN')
df_wgfa = quandl.get('UENV/WGFA_IDN')
df_bpco2 = quandl.get('BP/C02_EMMISSIONS_IDN')

# %%
df_bpco2.head(5)
# Out:
#                 Value
# Date
# 1965-12-31  20.140746
# 1966-12-31  19.548792
# 1967-12-31  18.687913
# 1968-12-31  19.614088
# 1969-12-31  21.292424

# %%
df_el_idn = quandl.get('UENG/EL_IDN')

# %%
df_el_idn
# Out:
#             Electricity - Gross production (Kilowatt-hours, million)  \
# Date
# 1990-12-31                                           48897.00
# 1991-12-31                                           51452.00
# 1992-12-31                                           54940.00
# 1993-12-31                                           58888.00
# 1994-12-31                                           64351.00
# 1995-12-31                                           68399.00
# 1996-12-31                                           78117.00
# 1997-12-31                                           84096.00
# 1998-12-31                                           76017.00
# 1999-12-31                                           95944.00
# 2000-12-31                                           99511.00
# 2001-12-31                                          101647.00
# 2002-12-31                                          108206.00
# 2003-12-31                                          112944.00
# ...
